# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\P.BHAVAN\\Desktop\\internship'

# %%
os.chdir("C:/Users/P.BHAVAN/Desktop/internship")
os.getcwd()
# Out:
# 'C:\\Users\\P.BHAVAN\\Desktop\\internship'

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %% [markdown]
# # Importing Dataset

# %%
data1=pd.read_csv(r'1. Master H1B Dataset.csv',encoding='ISO-8859-1',low_memory=False)
data1
# Out:
#         CASE_SUBMITTED_DAY  CASE_SUBMITTED_MONTH  CASE_SUBMITTED_YEAR  \
# 0                       24                     2                 2016
# 1                        4                     3                 2016
# 2                       10                     3                 2016
# 3                       28                     9                 2016
# 4                       22                     2                 2015
# ...                    ...                   ...                  ...
# 528129                  30                     6                 2017
# 528130                  30                     6                 2017
# 528131                  30                     6                 2017
# 528132                  30                     6                 2017
# 528133                  30                     6                 2017
#
#         DECISION_DAY  DECISION_MONTH  DECISION_YEAR     VISA_CLASS  \
# ...

# %%
data1.head()
# Out:
#    CASE_SUBMITTED_DAY  CASE_SUBMITTED_MONTH  CASE_SUBMITTED_YEAR  \
# 0                  24                     2                 2016
# 1                   4                     3                 2016
# 2                  10                     3                 2016
# 3                  28                     9                 2016
# 4                  22                     2                 2015
#
#    DECISION_DAY  DECISION_MONTH  DECISION_YEAR VISA_CLASS  \
# 0             1              10           2016        H1B
# 1             1              10           2016        H1B
# 2             1              10           2016        H1B
# 3             1              10           2016        H1B
# 4             2              10           2016        H1B
#
#                EMPLOYER_NAME EMPLOYER_STATE          EMPLOYER_COUNTRY  ...  \
# 0      DISCOVER PRODUCTS INC             IL  UNITED STATES OF AMERICA  ...
# ...

# %%
data1.describe()
# Out:
#        CASE_SUBMITTED_DAY  CASE_SUBMITTED_MONTH  CASE_SUBMITTED_YEAR  \
# count       528134.000000         528134.000000        528134.000000
# mean            15.246426              4.444859          2016.752854
# std              8.154979              3.201000             0.524568
# min              1.000000              1.000000          2011.000000
# 25%              8.000000              3.000000          2017.000000
# 50%             15.000000              3.000000          2017.000000
# 75%             22.000000              5.000000          2017.000000
# max             31.000000             12.000000          2017.000000
#
#         DECISION_DAY  DECISION_MONTH  DECISION_YEAR     NAICS_CODE  \
# count  528134.000000   528134.000000  528134.000000  528132.000000
# mean       16.565991        4.552377    2016.825876  443548.680673
# std         8.457420        3.201752       0.379217  197875.907540
# min         1.000000        1.000000    2016.000000      31.000000
# ...

# %%
data1.cov()
# Out:
#                        CASE_SUBMITTED_DAY  CASE_SUBMITTED_MONTH  \
# CASE_SUBMITTED_DAY              66.503689             -0.083616
# CASE_SUBMITTED_MONTH            -0.083616             10.246403
# CASE_SUBMITTED_YEAR             -0.168520             -1.147246
# DECISION_DAY                    13.977865             -0.714017
# DECISION_MONTH                   0.395189              9.003921
# DECISION_YEAR                   -0.047409             -1.009152
# NAICS_CODE                   13111.613740         -15307.749100
# TOTAL_WORKERS                   -0.044297             -0.054282
# PREVAILING_WAGE              -2514.309243           7137.337486
# PW_SOURCE_YEAR                  -0.082410             -0.208788
# WAGE_RATE_OF_PAY_FROM        -4509.336894           9387.228765
# WAGE_RATE_OF_PAY_TO           -758.155678           6828.565034
#
#                        CASE_SUBMITTED_YEAR  DECISION_DAY  DECISION_MONTH  \
# ...

# %%
data1.corr()
# Out:
#                        CASE_SUBMITTED_DAY  CASE_SUBMITTED_MONTH  \
# CASE_SUBMITTED_DAY               1.000000             -0.003203
# CASE_SUBMITTED_MONTH            -0.003203              1.000000
# CASE_SUBMITTED_YEAR             -0.039394             -0.683233
# DECISION_DAY                     0.202666             -0.026375
# DECISION_MONTH                   0.015135              0.878533
# DECISION_YEAR                   -0.015330             -0.831349
# NAICS_CODE                       0.008125             -0.024168
# TOTAL_WORKERS                   -0.001103             -0.003443
# PREVAILING_WAGE                 -0.009636              0.069686
# PW_SOURCE_YEAR                  -0.001817             -0.011725
# WAGE_RATE_OF_PAY_FROM           -0.013020              0.069053
# WAGE_RATE_OF_PAY_TO             -0.001774              0.040713
#
#                        CASE_SUBMITTED_YEAR  DECISION_DAY  DECISION_MONTH  \
# ...

# %%
data1.columns
# Out:
# Index(['CASE_SUBMITTED_DAY', 'CASE_SUBMITTED_MONTH', 'CASE_SUBMITTED_YEAR',
#        'DECISION_DAY', 'DECISION_MONTH', 'DECISION_YEAR', 'VISA_CLASS',
#        'EMPLOYER_NAME', 'EMPLOYER_STATE', 'EMPLOYER_COUNTRY', 'SOC_NAME',
#        'NAICS_CODE', 'TOTAL_WORKERS', 'FULL_TIME_POSITION', 'PREVAILING_WAGE',
#        'PW_UNIT_OF_PAY', 'PW_SOURCE', 'PW_SOURCE_YEAR', 'PW_SOURCE_OTHER',
#        'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY',
#        'H-1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'WORKSITE_STATE',
#        'WORKSITE_POSTAL_CODE', 'CASE_STATUS'],
#       dtype='object')

# %%
data1.dtypes
# Out:
# CASE_SUBMITTED_DAY         int64
# CASE_SUBMITTED_MONTH       int64
# CASE_SUBMITTED_YEAR        int64
# DECISION_DAY               int64
# DECISION_MONTH             int64
# DECISION_YEAR              int64
# VISA_CLASS                object
# EMPLOYER_NAME             object
# EMPLOYER_STATE            object
# EMPLOYER_COUNTRY          object
# SOC_NAME                  object
# NAICS_CODE               float64
# TOTAL_WORKERS              int64
# FULL_TIME_POSITION        object
# PREVAILING_WAGE          float64
# PW_UNIT_OF_PAY            object
# PW_SOURCE                 object
# PW_SOURCE_YEAR           float64
# PW_SOURCE_OTHER           object
# WAGE_RATE_OF_PAY_FROM    float64
# WAGE_RATE_OF_PAY_TO      float64
# WAGE_UNIT_OF_PAY          object
# H-1B_DEPENDENT            object
# WILLFUL_VIOLATOR          object
# WORKSITE_STATE            object
# WORKSITE_POSTAL_CODE      object
# CASE_STATUS               object
# dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528134 entries, 0 to 528133
# Data columns (total 27 columns):
# CASE_SUBMITTED_DAY       528134 non-null int64
# CASE_SUBMITTED_MONTH     528134 non-null int64
# CASE_SUBMITTED_YEAR      528134 non-null int64
# DECISION_DAY             528134 non-null int64
# DECISION_MONTH           528134 non-null int64
# DECISION_YEAR            528134 non-null int64
# VISA_CLASS               528134 non-null object
# EMPLOYER_NAME            528095 non-null object
# EMPLOYER_STATE           528124 non-null object
# EMPLOYER_COUNTRY         528134 non-null object
# SOC_NAME                 528134 non-null object
# NAICS_CODE               528132 non-null float64
# TOTAL_WORKERS            528134 non-null int64
# FULL_TIME_POSITION       528131 non-null object
# PREVAILING_WAGE          528134 non-null float64
# PW_UNIT_OF_PAY           528101 non-null object
# PW_SOURCE                528101 non-null object
# ...

# %%
data1['EMPLOYER_STATE'].unique()
# Out:
# array(['IL', 'DC', 'MI', 'NC', 'GA', 'NJ', 'IN', 'WA', 'TX', 'CA', 'OR',
#        'AR', 'NY', 'OK', 'RI', 'MA', 'WI', 'KY', 'IA', 'VA', 'FL', 'MD',
#        'DE', 'AZ', 'CT', 'LA', 'CO', 'MO', 'PA', 'MN', 'OH', 'UT', 'TN',
#        'KS', 'MS', 'SC', 'ND', 'VT', 'AL', 'ID', 'PR', 'GU', 'NH', 'NE',
#        'WV', 'NM', 'NV', 'ME', 'HI', 'MT', 'MP', 'SD', 'AK', 'WY', nan,
#        'VI', 'AS'], dtype=object)
